# %% [markdown]
# ## Create_Bronze_Raw_Cutshort_Jobs
#
# | Date         | Modified By      | Change Log             |
# |--------------|------------------|------------------------|
# | June 18th 2026| Yateesh Chandra  | Creating the Table : raw_cutshort_jobs |

# %%
spark.sql("""
        CREATE TABLE IF NOT EXISTS jobsintel.bronze.raw_cutshort_jobs (
            MESSAGE_ID BIGINT GENERATED ALWAYS AS IDENTITY COMMENT "The identity of the message entering the table sourcing from Cutshort",
            PAYLOAD STRING  COMMENT "The Json format of the data called from the API",
            BD_CREATE_DT_TM TIMESTAMP COMMENT "timestamp loaded",
            BD_UPDATE_DT_TM TIMESTAMP COMMENT "timestamp updated"
        )
        USING DELTA
 """)
